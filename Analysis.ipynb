# %%
# !pwd
# !make -C ./BlurEffect fullclean
# !make -C ./BlurEffectSequential fullclean
# Out:
# /home/fabiotovar/Proyectos/Paralell-Computing/Labs/ParallelComputingLabs
# make: Verzeichnis „/home/fabiotovar/Proyectos/Paralell-Computing/Labs/ParallelComputingLabs/BlurEffect“ wird betreten
# rm -R obj
# rm: das Entfernen von 'obj' ist nicht möglich: Datei oder Verzeichnis nicht gefunden
# Makefile:38: recipe for target 'clean' failed
# make: [clean] Error 1 (ignoriert)
# rm -R bin
# rm -R obj
# rm: das Entfernen von 'obj' ist nicht möglich: Datei oder Verzeichnis nicht gefunden
# Makefile:33: recipe for target 'fullclean' failed
# make: [fullclean] Error 1 (ignoriert)
# rm -R out
# make: Verzeichnis „/home/fabiotovar/Proyectos/Paralell-Computing/Labs/ParallelComputingLabs/BlurEffect“ wird verlassen
# make: Verzeichnis „/home/fabiotovar/Proyectos/Paralell-Computing/Labs/ParallelComputingLabs/BlurEffectSequential“ wird betreten
# rm -R obj
# rm: das Entfernen von 'obj' ist nicht möglich: Datei oder Verzeichnis nicht gefunden
# Makefile:38: recipe for target 'clean' failed
# make: [clean] Error 1 (ignoriert)
# rm -R bin
# rm -R obj
# rm: das Entfernen von 'obj' ist nicht möglich: Datei oder Verzeichnis nicht gefunden
# Makefile:33: recipe for target 'fullclean' failed
# make: [fullclean] Error 1 (ignoriert)
# rm -R out
# make: Verzeichnis „/home/fabiotovar/Proyectos/Paralell-Computing/Labs/ParallelComputingLabs/BlurEffectSequential“ wird verlassen

# %%
# !make -C ./BlurEffect
# !make -C ./BlurEffectSequential
# Out:
# make: Verzeichnis „/home/fabiotovar/Proyectos/Paralell-Computing/Labs/ParallelComputingLabs/BlurEffect“ wird betreten
# gcc -Wall -pedantic -c src/blur_effect.c -o obj/blur_effect.o
# gcc -pg -o bin/blur-effect obj/blur_effect.o -lm -lpthread
# rm -R obj
# make: Verzeichnis „/home/fabiotovar/Proyectos/Paralell-Computing/Labs/ParallelComputingLabs/BlurEffect“ wird verlassen
# make: Verzeichnis „/home/fabiotovar/Proyectos/Paralell-Computing/Labs/ParallelComputingLabs/BlurEffectSequential“ wird betreten
# gcc -Wall -pedantic -c src/blur_effect.c -o obj/blur_effect.o
# gcc -o bin/blur-effect obj/blur_effect.o -fopenmp -lm
# rm -R obj
# make: Verzeichnis „/home/fabiotovar/Proyectos/Paralell-Computing/Labs/ParallelComputingLabs/BlurEffectSequential“ wird verlassen

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /home/fabiotovar/.local/lib/python3.6/site-packages (7.1.1)
# WARNING: You are using pip version 19.1.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# ## Gaussian Filter

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %matplotlib inline

# %%
# !./BlurEffect/bin/blur-effect ./BlurEffect/img/test.png ./test.png 15 4 2.3 1
# Out:
# Image dimensions: (800px, 820px) and 3 channels.
# Image created
# Time elapsed: 1.506123

# %%
fig = plt.figure(figsize=(16, 16))

pil_im = Image.open('./BlurEffect/img/test.png', 'r')
fig.add_subplot(1, 2, 2)
plt.imshow(np.asarray(pil_im));

pil_im = Image.open('./test.png', 'r')
fig.add_subplot(1, 2, 1)
plt.imshow(np.asarray(pil_im));

plt.show()

# %%
# !./BlurEffect/bin/blur-effect ./BlurEffect/img/test720.jpg ./test720.jpg 15 4 2.3 1
# Out:
# Image dimensions: (1280px, 720px) and 3 channels.
# Image created
# Time elapsed: 2.288946

# %%
fig = plt.figure(figsize=(16, 16))

pil_im = Image.open('./BlurEffect/img/test720.jpg', 'r')
fig.add_subplot(1, 2, 1)
plt.imshow(np.asarray(pil_im));

pil_im = Image.open('./test720.jpg', 'r')
fig.add_subplot(1, 2, 2)
plt.imshow(np.asarray(pil_im));

plt.show()

# %% [markdown]
# ### Kernel variations

# %% [markdown]
# ### Sigma variations

# %%
# !./BlurEffect/bin/blur-effect ./BlurEffect/img/test720.jpg ./test720_1.jpg 15 4 1 0
# !./BlurEffect/bin/blur-effect ./BlurEffect/img/test720.jpg ./test720_2.jpg 15 4 2.3 0
# !./BlurEffect/bin/blur-effect ./BlurEffect/img/test720.jpg ./test720_5.jpg 15 4 5 0
# !./BlurEffect/bin/blur-effect ./BlurEffect/img/test720.jpg ./test720_20.jpg 15 4 20 0
# Out:
# 2.308951
# 2.245859
# 2.273603
# 2.513750

# %%
fig = plt.figure(figsize=(16, 10))

pil_im = Image.open('./test720_1.jpg', 'r')
fig.add_subplot(2, 2, 1)
plt.imshow(np.asarray(pil_im));

pil_im = Image.open('./test720_2.jpg', 'r')
fig.add_subplot(2, 2, 2)
plt.imshow(np.asarray(pil_im));

pil_im = Image.open('./test720_5.jpg', 'r')
fig.add_subplot(2, 2, 3)
plt.imshow(np.asarray(pil_im));

pil_im = Image.open('./test720_20.jpg', 'r')
fig.add_subplot(2, 2, 4)
plt.imshow(np.asarray(pil_im));

plt.show()

# %% [markdown]
# ### Kernel size variation

# %%
# !./BlurEffect/bin/blur-effect ./BlurEffect/img/test720.jpg ./test720_33.jpg 3 4 5 0
# !./BlurEffect/bin/blur-effect ./BlurEffect/img/test720.jpg ./test720_55.jpg 5 4 5 0
# !./BlurEffect/bin/blur-effect ./BlurEffect/img/test720.jpg ./test720_77.jpg 7 4 5 0
# !./BlurEffect/bin/blur-effect ./BlurEffect/img/test720.jpg ./test720_3131.jpg 31 4 5 0
# Out:
# 0.657217
# 0.751462
# 0.914339
# 7.488498

# %%
fig = plt.figure(figsize=(16, 10))

pil_im = Image.open('./test720_33.jpg', 'r')
fig.add_subplot(2, 2, 1)
plt.imshow(np.asarray(pil_im));

pil_im = Image.open('./test720_55.jpg', 'r')
fig.add_subplot(2, 2, 2)
plt.imshow(np.asarray(pil_im));

pil_im = Image.open('./test720_77.jpg', 'r')
fig.add_subplot(2, 2, 3)
plt.imshow(np.asarray(pil_im));

pil_im = Image.open('./test720_3131.jpg', 'r')
fig.add_subplot(2, 2, 4)
plt.imshow(np.asarray(pil_im));

plt.show()

# %% [markdown]
# ## Test bench

# %%
# !rm out.out

# %%
# !./test-bench.sh BlurEffect/img/test720.jpg
# Out:
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K3_T1.jpg 3 1
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K3_T2.jpg 3 2
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K3_T4.jpg 3 4
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K3_T8.jpg 3 8
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K3_T16.jpg 3 16
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K3_T32.jpg 3 32
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K5_T1.jpg 5 1
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K5_T2.jpg 5 2
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K5_T4.jpg 5 4
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K5_T8.jpg 5 8
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K5_T16.jpg 5 16
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K5_T32.jpg 5 32
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K7_T1.jpg 7 1
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K7_T2.jpg 7 2
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K7_T4.jpg 7 4
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K7_T8.jpg 7 8
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K7_T16.jpg 7 16
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K7_T32.jpg 7 32
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K9_T1.jpg 9 1
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K9_T2.jpg 9 2
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K9_T4.jpg 9 4
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K9_T8.jpg 9 8
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K9_T16.jpg 9 16
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K9_T32.jpg 9 32
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K11_T1.jpg 11 1
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K11_T2.jpg 11 2
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K11_T4.jpg 11 4
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K11_T8.jpg 11 8
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K11_T16.jpg 11 16
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K11_T32.jpg 11 32
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K13_T1.jpg 13 1
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K13_T2.jpg 13 2
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K13_T4.jpg 13 4
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K13_T8.jpg 13 8
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K13_T16.jpg 13 16
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K13_T32.jpg 13 32
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K15_T1.jpg 15 1
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K15_T2.jpg 15 2
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K15_T4.jpg 15 4
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K15_T8.jpg 15 8
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K15_T16.jpg 15 16
# #./BlurEffect/bin/blur-effect BlurEffect/img/test720.jpg ./BlurEffect/out/test720_K15_T32.jpg 15 32

# %%
import pandas as pd

data = pd.read_csv('out2.out', sep=" ", header=None)
threads = [1, 2, 4, 8, 16, 32]
K = [3, 5, 7, 9, 11, 13, 15]

# %%
processed = pd.DataFrame(np.zeros((len(K), len(threads))), columns=threads, index=K)
k = 0
for i in range(len(K)):
    for j in range(len(threads)):
        if k < data.shape[0]:
         processed.iloc[i, j] = data.iloc[k][0]
        k += 1

# %%
processed.plot(figsize=(6,3))
processed.shape
# Out:
# (7, 6)

# %%
fig = plt.figure(figsize=(16, 10))

for i in range(processed.shape[1]):
    #print(processed.iloc[1, i])
    fig.add_subplot(4, 2, i + 1)
    plt.plot(processed.iloc[i])

plt.show()

# %%
fig = plt.figure(figsize=(16, 10))

for i in range(processed.shape[1]):
    fig.add_subplot(4, 2, i + 1)
    plt.plot(processed.iloc[:, i])

plt.show()
